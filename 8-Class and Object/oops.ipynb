# %% [markdown]
# Classes and Object

# %% [markdown]
# Object Oriented Programming (OOP) is a Programming Paradigm that uses "Object" to design application and computer program. OOPs allos for modeling real world scenario using classes and object.

# %%
## class is nothing but a blueprint for creating objects, Attributes,methods.
class car:
    pass
audi =car()
bmw =car()

print(type(audi))
# Out:
# <class '__main__.car'>

# %%
audi.windows = 4
print(audi.windows)
# Out:
# 4

# %%
tata = car()
tata.door = 4
print(tata.windows)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 3
#       1 tata = car()
#       2 tata.door = 4
# ----> 3 print(tata.windows)
#
# AttributeError: 'car' object has no attribute 'windows'

# %%
dir(tata)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'door']

# %%
## Instance Variable and Methods

class dog:
    #constructor
    def __init__(self,name,age):
        self.name = name
        self.age = age
        
#create object
dog1 = dog("Buddy",3)
print(dog1)
print(dog1.name)
print(dog1.age)
# Out:
# ...
# Buddy
# 3

# %%
dog2 = dog("Lucky",4)
print(dog2.name)
print(dog2.age)
# Out:
# Lucky
# 4

# %%
## Define a class with instance methods

class Dog:
    def __init__(self,name,age):
        self.name = name
        self.age = age
    
    def bark(self):
        print(f"{self.name} says woof")
        
dog1 = Dog("buddy",4)
dog1.bark()
dog2 = Dog("lucky",20)
dog2.bark()
# Out:
# buddy says woof
# lucky says woof

# %%
### Modeling a Bank account

## Defining a class for bank account

class BankAccount:
    def __init__(self,owner,balance=0):
        self.owner = owner
        self.balance = balance
        
    def deposite(self,amount):
        self.balance+= amount
        print(f"{amount} is Deposited. New Balance {self.balance}")
        
    def withdrwal(self,amount):
        if amount>self.balance:
            print("Insufficient funds!")
        else:
            self.balance-= amount
            print(f"{amount} is Withdrawl.New Balance {self.balance}")
            
    def get_balance(self):
        return self.balance
    
## create an account {object}

account = BankAccount("saif",50000)
print(account.balance)
# Out:
# 50000

# %%
## call Instance methods

account.deposite(5000)
# Out:
# 5000 is Deposited. New Balance 55000

# %%
account.withdrwal(10000)
# Out:
# 10000 is Withdrawl.New Balance 45000

# %%
account.get_balance()
# Out:
# 45000
