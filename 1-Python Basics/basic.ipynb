# %%
## bacis syntax rules in python
## Python is case-senstive

name= 'saif'
Name= 'abbas'

# %%
##indentation

age= 32
if age>30:
    
    print(age)
    
print(age)
# Out:
# 32
# 32

# %%
##line continuation
## use backslash to continue a line of code to the next line  

total = 1+2+3+4+5+5+6+6+7+\
    8+9+10
    
print(total)
# Out:
# 66

# %%
x = 10 ;y =20;z =x+y
print(z)
# Out:
# 30

# %%
variable = 10
print(type(variable))
variable ="saif"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>

# %%
if True:
    print("this is true")
    if False:
        priint("this is false")
    print("this is still true")
print("this is outside the if statment")
# Out:
# this is true
# this is still true
# this is outside the if statment
