# %%
## declaring and assinging the variable

age = 23
height = 5.9
name  ="saif abbas"
is_student = True

print("age:", age)
print("height:", height)
print("name:", name)
print("is_student", is_student)
# Out:
# age: 23
# height: 5.9
# name: saif abbas
# is_student True

# %%
## valid variable names
first_name = "john"
last_name ="doe"

# %%
##invalid variable names
#1name = "john" # cannot start with a number

# %%
name = "saif"
Name = "abbas"

name == Name
# Out:
# False

# %%
name = "saif"
Name = "saif"

name == Name
# Out:
# True

# %%
#type conversation
age = 23
print(type(age))

age_str = str(age)
print(age_str)
print(type(age_str))
# Out:
# <class 'int'>
# 23
# <class 'str'>

# %%
age = '23'
print(type(age))
print(type(int(age)))
# Out:
# <class 'str'>
# <class 'int'>

# %%
## Dynamic typing

var = 10 
print(var,type(var))

var = "hello"
print(var,type(var))

var = 5.67
print(var,type(var))
# Out:
# 10 <class 'int'>
# hello <class 'str'>
# 5.67 <class 'float'>

# %%
# input function
name = input ("Enter your name:")
print("Your name is:", name)
print("Your name is:",type(name))
# Out:
# Your name is: saifu
# Your name is: <class 'str'>

# %%
# calculator

num1 = float(input("Enteer first number:"))
num2 = float(input("Enter second number:"))

sum = num1 + num2
difference = num1 - num2
product = num1 * num2
quotient = num1 / num2

print("sum:", sum)
print("difference:", difference)
print("product:", product)
print("quotient:", quotient)
# Out:
# sum: 66.0
# difference: 46.0
# product: 560.0
# quotient: 5.6
