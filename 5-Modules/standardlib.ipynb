# %%
import array 
arr = array.array('i', [1, 2, 3, 4, 5])
print(arr)
# Out:
# array('i', [1, 2, 3, 4, 5])

# %%
import math 
print(math.sqrt(36))
print(math.pi)
# Out:
# 6.0
# 3.141592653589793

# %%
 # random module

import random
print(random.randint(1, 10))
print(random.choice(['apple', 'banana', 'cherry']))
# Out:
# 7
# cherry

# %%
# file and directory access

import os   
print(os.getcwd())  # get current working directory
print(os.listdir())  # list files in current directory
# Out:
# /Users/saif/Documents/Source code/python udemy/5- Modules
# ['test.py', 'importmodule.ipynb', 'standardlib.ipynb', 'package']

# %%
# high level operation on files and collection of files

import shutil
shutil.copy("source.txt","destination.txt")
# Out:
# 'destination.txt'

# %%
# data serialization
import json
data ={"name":"saif","age":23}
json_str = json.dumps(data)
print(json_str)
print(type(json_str))

parsed_data = json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "saif", "age": 23}
# <class 'str'>
# {'name': 'saif', 'age': 23}
# <class 'dict'>

# %%
#csv

import csv
with open('example.csv',mode = 'w',newline='') as file:
    writer =csv.writer(file)
    writer.writerow(["name","age"])
    writer.writerow(["saif",23])

with open('example.csv',mode='r') as file:
    reader =csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['saif', '23']

# %%
# datetime

from datetime import datetime,timedelta

now = datetime.now()
print(now)

yesterday = now-timedelta(days=1)
print(yesterday)
# Out:
# 2026-02-12 00:38:22.735369
# 2026-02-11 00:38:22.735369

# %%
## time

import time
print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1770837024.3045602
# 1770837026.3099608

# %%
# regular expression

import re

pattern = r'\d+'
text = "There are 123 apples"
match = re.search(pattern,text)
print(match.group())
# Out:
# 123
