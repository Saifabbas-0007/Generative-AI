# %%
daily_pints ={1,2,3}
type(daily_pints)
# Out:
# set

# %%
print(daily_pints)
# Out:
# {1, 2, 3}

# %%
daily_pints_logs ={1,2,3,4,5,1,2,3,4,31}
print(daily_pints_logs)
# Out:
# {1, 2, 3, 4, 5, 31}

# %%
daily_pints_logs={1,2,3,4,1,2,31,34,43}
my_daily_pints_logs={1,2,3,24,33,34,45,2,2,2,2,2,2,55}
print(daily_pints_logs| my_daily_pints_logs) #different in both sets
# Out:
# {1, 2, 3, 4, 34, 33, 43, 45, 55, 24, 31}

# %%
print(daily_pints_logs & my_daily_pints_logs) #matches in both
# Out:
# {1, 2, 3, 34}

# %%
print(daily_pints_logs - my_daily_pints_logs)
# Out:
# {43, 4, 31}

# %%
print(my_daily_pints_logs - daily_pints_logs)
# Out:
# {24, 33, 45, 55}

# %%
print(daily_pints_logs ^ my_daily_pints_logs) # not in both set only in one set
# Out:
# {33, 4, 43, 45, 55, 24, 31}
