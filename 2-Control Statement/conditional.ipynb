# %%
## if statements

age = 20

if age >= 18:
    print("you are an adult")
# Out:
# you are an adult

# %%
 ## else statement

age = 16

if age >= 18:
    print("you are an adult")
else:
    print("you are a minor")
# Out:
# you are a minor

# %%
##elif statement
## allow to check multiple conditions

age = 16

if age < 15:
    print("you are a child")
elif age < 18:
    print("you are a teenager")
else:
    print("you are an adult")
# Out:
# you are a teenager

# %%
## nested statements

num = int(input("enter a number: "))
if num > 0:
    print("positive number")
    if num % 2 == 0:
        print("even number")
    else:
        print("odd number")
else:
    print("negative number")
# Out:
# positive number
# odd number

# %%
year = int(input("enter a year: "))
if year % 4 == 0 :
    if year % 100 == 0:
        if year % 400 == 0:
            print("leap year")
        else:
            print("not a leap year")
    else:
        print("leap year")
else:
    print("not a leap year")
# Out:
# not a leap year

# %%
## simple calculator
num1 = float(input("enter first number: "))
num2 = float(input("enter second number: "))
operator = input("enter operator (+, -, *, /): ")   

if operator == "+":
    result = num1 + num2
    print("result: ", result)
elif operator == "-":
    result = num1 - num2
    print("result: ", result)
elif operator == "*":          
    result = num1 * num2
    print("result: ", result)
elif operator == "/":
    if num2 != 0:
        result = num1 / num2
        print("result: ", result)
    else:
        print("error: division by zero")
else:   
     print("invalid operator")
# Out:
# result:  44.0

# %%
## determine the ticket price based on age whether the person is student

age  = int(input("Enter your age:"))
is_student = input("Are you a student? (yes/no):").lower() # why use lower() method? to convert the input to lowercase so that we can compare it with "yes" and "no" without worrying about the case sensitivity.

if age < 5:
    print("free ticket")
elif age <=15:
    print("ticket price: $8")
elif age <= 18:
    if is_student =="yes":
        print("ticket price: $10")
    else:
        print("ticket price: $12")
elif age <= 30:
    if is_student == "yes":
        print("ticket price: $15")
    else:
        print("ticket price: $20")
else:
    print("ticket price: $25")
# Out:
# ticket price: $15
